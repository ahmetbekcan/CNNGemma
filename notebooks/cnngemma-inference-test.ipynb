# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))
from utils import load_finetuned_model
import torch

from inference import inference
from cnn_gemma import CNNGemmaConfig
from processing_cnngemma import CNNGemmaProcessor
import json

image_file_path = "..\\dataset\\RISCM\\resized\\NWPU_361.jpg"
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
with open("../src/configs/mobilenet_single.json", "r") as f:
    model_config_file = json.load(f)

config = CNNGemmaConfig(**model_config_file)
model, tokenizer = load_finetuned_model(model_path="../src/weights/mobilenet_single",hub_id="ahmetbekcan/CNNGemma-MobileNet-Single-224",device="cuda", config=config, dtype=torch.bfloat16)
processor = CNNGemmaProcessor(tokenizer=tokenizer,num_image_tokens=model.config.vision_config.num_image_tokens, image_encoder_type=model.config.vision_config.architecture)

prediction = inference(model, processor, prompt="caption en", image_file_path=image_file_path, device=device, do_sample=False)
print(prediction)
# Out:
# c:\Users\USER\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\USER\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Large_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Running inference
# a view of the beach

# %%
with open("../src/configs/mobilenet_multiple.json", "r") as f:
    model_config_file = json.load(f)

config = CNNGemmaConfig(**model_config_file)
model, tokenizer = load_finetuned_model(model_path="../src/weights/mobilenet_multiple",hub_id="ahmetbekcan/CNNGemma-MobileNet-Multiple-224",device="cuda", config=config, dtype=torch.bfloat16)
processor = CNNGemmaProcessor(tokenizer=tokenizer,num_image_tokens=model.config.vision_config.num_image_tokens, image_encoder_type=model.config.vision_config.architecture)

prediction = inference(model, processor, prompt="caption en", image_file_path=image_file_path, device=device, do_sample=False)
print(prediction)
# Out:
# c:\Users\USER\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\USER\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Large_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Running inference
# the square is surrounded by buildings and a few cars

# %%
with open("../src/configs/efficientnet_single.json", "r") as f:
    model_config_file = json.load(f)

config = CNNGemmaConfig(**model_config_file)
model, tokenizer = load_finetuned_model(model_path="../src/weights/efficientnet_single",hub_id="ahmetbekcan/CNNGemma-EfficientNet-Single-224",device="cuda", config=config, dtype=torch.bfloat16)
processor = CNNGemmaProcessor(tokenizer=tokenizer,num_image_tokens=model.config.vision_config.num_image_tokens, image_encoder_type=model.config.vision_config.architecture)

prediction = inference(model, processor, prompt="caption en", image_file_path=image_file_path, device=device, do_sample=False)
print(prediction)
# Out:
# c:\Users\USER\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\USER\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Running inference
# the most popular tags for this image include : love and romance

# %%
with open("../src/configs/efficientnet_multiple.json", "r") as f:
    model_config_file = json.load(f)

config = CNNGemmaConfig(**model_config_file)
model, tokenizer = load_finetuned_model(model_path="../src/weights/efficientnet_multiple",hub_id="ahmetbekcan/CNNGemma-EfficientNet-Multiple-224",device="cuda", config=config, dtype=torch.bfloat16)
processor = CNNGemmaProcessor(tokenizer=tokenizer,num_image_tokens=model.config.vision_config.num_image_tokens, image_encoder_type=model.config.vision_config.architecture)

prediction = inference(model, processor, prompt="caption en", image_file_path=image_file_path, device=device, do_sample=False)
print(prediction)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/5.03G [00:00<?, ?B/s]
# c:\Users\USER\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\USER\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Running inference
# the most expensive car in the world
